# %%
# Salary Prediction using Linear Regression

## Objective
#To predict salary based on years of experience and analyze the relationship between them.

## Dataset
#Salary dataset with YearsExperience and Salary.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#load data

df = pd.read_csv("Salary_Data (1).csv")
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#EDA

print(df.describe())
print(df.isnull().sum())

sns.scatterplot(x='YearsExperience', y='Salary', data=df)
plt.title("Experience vs Salary")
plt.show()

sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
#Model

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X = df[['YearsExperience']]
y = df['Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [ 81482.67852947 125606.45244988  90115.59081824  35440.47965599
#   55583.94166313  45991.81689783]

# %%
#Evaluation

from sklearn.metrics import r2_score, mean_squared_error

print("R2:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2: 0.9711324324542351
# RMSE: 4959.17762519612

# %%
#Visualizations

plt.figure(figsize=(10,5))
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', label='Prediction')
plt.legend()
plt.title("Salary Prediction Dashboard")
plt.show()
